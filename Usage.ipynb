# %%
load('~/host/FindingSystoles.sage')

# %%
#Initializing the Group 
G = SignatureGroup([48,29],[8,3,2])
K = G.signature_generated #GAP Group with the generators of the desired order

gens = G.generators
x = gens[0]
y = gens[1]
z = gens[2]

# %%
#Reduction of words
G.reduction(y^2)
# Out:
# F1*F2*F1

# %%
#Initializing the Polygon
Poly = FundamentalPolygon_mn2([48,29],[8,3,2])
Poly.genus()
# Out:
# 2

# %%
Poly.draw()
# Out:
# Graphics object consisting of 194 graphics primitives

# %%
#Generators of the Fuchsian group
Poly.rotations_quadrilateral
# Out:
# [
# [0.707106781186548 + 0.707106781186548*I                       0.000000000000000]  [-0.664524664599176 + 0.866025403784439*I 0.696537817204207 - 0.0917009432990069*I]
# [                      0.000000000000000                        1.00000000000000], [-0.427684255050040 + 0.557368972745902*I   1.08226233229959 - 0.142482539092001*I]
# ]

# %%
Quad = Poly.draw_quadrilateral()
Quad
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
#Initializing the Polygon for families
F = FundamentalPolygon_m222([12,4],[3,2,2,2],pi/2)
F.genus()
# Out:
# 2

# %%
F.draw()
# Out:
# Graphics object consisting of 73 graphics primitives

# %%
#Generators of the Fuchsian group
F.rotations_hexagon
# Out:
# [
# [-0.500000000000000 + 0.866025403784439*I                        0.000000000000000]  [                       -1.17157287525381  0.717438935214301 + 0.414213562373095*I]  [                          -1.17157287525381  2.34674304955811e-16 + 0.828427124746190*I]  [   -1.02943725152286 + 0.594345874280551*I 2.22044604925031e-16 + 0.970562748477140*I]
# [                       0.000000000000000                         1.00000000000000], [-0.717438935214301 + 0.414213562373095*I                         1.17157287525381], [-2.34674304955811e-16 + 0.828427124746190*I                            1.17157287525381], [   0.840531996148050 + 0.485281374238570*I     1.02943725152286 - 0.594345874280551*I]
# ]

# %%
F.draw_hexagon()
# Out:
# Graphics object consisting of 6 graphics primitives
